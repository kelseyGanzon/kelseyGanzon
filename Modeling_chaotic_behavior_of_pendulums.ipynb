# %%
import math

import numpy as np
import matplotlib.pyplot as plt


def g(x, y, z):
    return -.1*z - 4*y + math.cos(x)

def f(x, t, v):
    k1 = g(0, 0, 0)*t
    k2 = g()*t
    k3 = g()*t
    k4 = g()*t
    y_next = x + 1/6*(k1 + 2*k2 + 2*k3 + k4)


def henonMap(x, y, a, b):
    x_next = y + 1 - a * x**2
    y_next = b * x
    return x_next, y_next


iterations = 10000
X = np.zeros(iterations + 1)
Y = np.zeros(iterations + 1)

X[0], Y[0] = 0, 0

for i in range(iterations):
    x_next, y_next = henonMap(X[i], Y[i], 1.4, 0.3)
    X[i + 1] = x_next
    Y[i + 1] = y_next

plt.plot(X, Y, '^', markersize=0.1, color='blue')
plt.axis('off')
plt.show()

X = np.zeros(iterations + 1)
Y = np.zeros(iterations + 1)
X[0], Y[0] = 0.1, 0.1
for i in range(iterations):
    x_next, y_next = henonMap(X[i], Y[i], 1.4, 0.3)
    X[i + 1] = x_next
    Y[i + 1] = y_next

plt.plot(X, Y, '^', markersize=0.1, color='red')
plt.axis('off')
plt.show()
plt.close()


def g(x, y, z):
    return -.1*z - 4*y + math.cos(x)
def f(x, y, z):
    return z
def rungeKutta(x0, y0, z0, h):
    for i in range(1, 10):
        k0 = h * f(x0, y0, z0)
        l0 = h * g(x0, y0, z0)
        k1 = h * f(x0 + h/2, y0 + k0/2, z0 + l0/2)
        l1 = h * g(x0 + h/2, y0 + k0/2, z0 + l0/2)
        k2 = h * f(x0 + h/2, y0 + k1/2, z0 + l1/2)
        l2 = h * g(x0 + h/2, y0 + k1 / 2, z0 + l1/2)
        k3 = h * f(x0 + h / 2, y0 + k2 / 2, z0 + l2 / 2)
        l3 = h * g(x0 + h / 2, y0 + k2 / 2, z0 + l2 / 2)

        y_next = y0 + (1.0 / 6.0) * (k0 + 2*k1 + 2*k2 + k3)
        z_next = z0 + (1.0 / 6.0) * (l0 + 2*l1 + l3)
    return y_next, z_next


X = np.zeros(iterations + 1)
Y = np.zeros(iterations + 1)
Z = np.zeros(iterations + 1)
X[0], Y[0], Z[0] = 0, 0, 0
for i in range(iterations):
    y_next, z_next = rungeKutta(X[i], Y[i], Z[i], 0.1)
    Y[i + 1] = y_next
    Z[i + 1] = z_next

plt.plot(Y, Z, '^', markersize=0.1, color='purple')
plt.show()

# %%
def vdot(t,x,v):
  return -.1*v-4*x+np.cos(t)
def RK3(f,t,x0,v0,dt)

# %%
import math

import numpy as np
import matplotlib.pyplot as plt


def vdot(t,x,v):
    return -.1* v - 4 * x + np.cos(t)

def RK2(f, t, x0, v0, dt):
    k1 = f(t, x0, v0)
    dx = v0 * dt
    k2 = f(t + dt, x0 + dx, v0 + dx*k1)
    k3= f(t + dt/2, x0 +dx, v0 + (dt/4) * (k1+k2))
    v1 = v0 + (dt/6) * (k1 + k2 + 4*k3)
    x1 = x0 + dx
    return x1, v1

xs = [0]; vs = [0]; dt = 0.01; T = 100; N=int(T/dt)
ts= np.linspace(0,T,N)
for i in range(1,N):
  x1,v1 = RK2(vdot,ts[i-1],xs[i-1],vs[i-1],dt)
  xs.append(x1)
  vs.append(v1)


plt.plot(ts,xs)
plt.grid()
plt.plot(ts,)

# %%
import math

import numpy as np
import matplotlib.pyplot as plt


def vdot(t,x,v):
    return -.1*v - np.sin(x) + 0.6*np.cos(0.9*t)

def RK2(f, t, x0, v0, dt):
    k1 = dt*f(t, x0, v0)
    dx = v0 * dt
    k2 = dt * f(t + dt, x0 + dx, v0 + k1)
    v1 = v0 + (1/2) * (k1+k2)
    x1 = x0 + dx
    return x1, v1

xs = [0]; vs = [0]; dt = 0.01; T = 100; N=int(T/dt)
ts= np.linspace(0,T,N)
for i in range(1,N):
  x1,v1 = RK2(vdot,ts[i-1],xs[i-1],vs[i-1],dt)
  xs.append(x1)
  vs.append(v1)
plt.plot(ts,xs)
# Out:
# Text(0.5, 1.0, 'v vs t')

# %%
import math

import numpy as np
import matplotlib.pyplot as plt


def vdot(t,x,v):
    return -.1*v - np.sin(x) + 1.22*np.cos(0.9*t)

def RK2(f, t, x0, v0, dt):
    k1 = dt*f(t, x0, v0)
    dx = v0 * dt
    k2 = dt * f(t + dt, x0 + dx, v0 + k1)
    v1 = v0 + (1/2) * (k1+k2)
    x1 = x0 + dx
    return x1, v1

xs = [0]; vs = [0]; dt = 0.01; T = 100; N=int(T/dt)
ts= np.linspace(0,T,N)
for i in range(1,N):
  x1,v1 = RK2(vdot,ts[i-1],xs[i-1],vs[i-1],dt)
  xs.append(x1)
  vs.append(v1)
plt.plot(ts,xs)

# %% [markdown]
# Heres what we did
#
#
# *   First part of the code was a Runge Kutta model which is an iterative method used for approximating solutions of simultaneous nonlinear equations.
# *   A heno map of a simplied poincre section was plotted and is chaotic but later analyzed to converge to a periodic orbit
# *   The next part was understanding the periodic behavior of a the pendulum after an elasped time has passed
# *   After a certain amount of itteraitons, the pendulum shows chaotic behavior and then result back to periodic behavior
# *   This simulation was analyzing how a damped pendulum on a vibrating ceiling behaves and how it affects its periodicity
